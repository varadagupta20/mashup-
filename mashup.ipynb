# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
pip install pydub
# Out:
# Requirement already satisfied: pydub in /opt/conda/lib/python3.10/site-packages (0.25.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pytube
# Out:
# Collecting pytube
#   Downloading pytube-15.0.0-py3-none-any.whl.metadata (5.0 kB)
# Downloading pytube-15.0.0-py3-none-any.whl (57 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 893.9 kB/s eta 0:00:000:00:01
# Installing collected packages: pytube
# Successfully installed pytube-15.0.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install moviepy
# Out:
# Collecting moviepy
#   Downloading moviepy-1.0.3.tar.gz (388 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 388.3/388.3 kB 2.3 MB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# Collecting decorator<5.0,>=4.0.2 (from moviepy)
#   Downloading decorator-4.4.2-py2.py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: tqdm<5.0,>=4.11.2 in /opt/conda/lib/python3.10/site-packages (from moviepy) (4.66.1)
# Requirement already satisfied: requests<3.0,>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from moviepy) (2.31.0)
# Collecting proglog<=1.0.0 (from moviepy)
#   Downloading proglog-0.1.10-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: numpy>=1.17.3 in /opt/conda/lib/python3.10/site-packages (from moviepy) (1.26.4)
# Requirement already satisfied: imageio<3.0,>=2.5 in /opt/conda/lib/python3.10/site-packages (from moviepy) (2.33.1)
# Collecting imageio_ffmpeg>=0.2.0 (from moviepy)
#   Downloading imageio_ffmpeg-0.4.9-py3-none-manylinux2010_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=8.3.2 in /opt/conda/lib/python3.10/site-packages (from imageio<3.0,>=2.5->moviepy) (9.5.0)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from imageio_ffmpeg>=0.2.0->moviepy) (69.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3.0,>=2.8.1->moviepy) (2024.2.2)
# Downloading decorator-4.4.2-py2.py3-none-any.whl (9.2 kB)
# Downloading imageio_ffmpeg-0.4.9-py3-none-manylinux2010_x86_64.whl (26.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 40.4 MB/s eta 0:00:00:00:0100:01
# Downloading proglog-0.1.10-py3-none-any.whl (6.1 kB)
# Building wheels for collected packages: moviepy
#   Building wheel for moviepy (setup.py) ... done
#   Created wheel for moviepy: filename=moviepy-1.0.3-py3-none-any.whl size=110720 sha256=d9ceda7779f85680d3961da3eb60dc3c2a1b26b4ffc6c6b1dc1c4ae7e481325a
#   Stored in directory: /root/.cache/pip/wheels/96/32/2d/e10123bd88fbfc02fed53cc18c80a171d3c87479ed845fa7c1
# Successfully built moviepy
# Installing collected packages: proglog, imageio_ffmpeg, decorator, moviepy
#   Attempting uninstall: decorator
#     Found existing installation: decorator 5.1.1
#     Uninstalling decorator-5.1.1:
#       Successfully uninstalled decorator-5.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2023.12.2.post1 requires fsspec==2023.12.2, but you have fsspec 2024.2.0 which is incompatible.
# Successfully installed decorator-4.4.2 imageio_ffmpeg-0.4.9 moviepy-1.0.3 proglog-0.1.10
# Note: you may need to restart the kernel to use updated packages.

# %%
from pytube import YouTube
from moviepy.editor import VideoFileClip
from pydub import AudioSegment

video_urls = [
    "https://www.youtube.com/watch?v=syFZfO_wfMQ",
    "https://www.youtube.com/watch?v=UpsKGvPjAgw",
    "https://www.youtube.com/watch?v=QJO3ROT-A4E",
    "https://www.youtube.com/watch?v=36mCEZzzQ3o",
    "https://www.youtube.com/watch?v=T4cdfRohhcg",
    "https://www.youtube.com/watch?v=R1Pmcy74Kfs",
    "https://www.youtube.com/watch?v=Ho32Oh6b4jc",
    "https://www.youtube.com/watch?v=yjmp8CoZBIo",
    "https://www.youtube.com/watch?v=PJYpZ4hkXJE",
    "https://www.youtube.com/watch?v=RgKAFK5djSk"
    
]

for url in video_urls:
    try:
        yt = YouTube(url)
        
        stream = yt.streams.get_highest_resolution()
        video_path = stream.download()
        
        print(f"Downloaded: {yt.title}")
        
        mp3_path = video_path[:-4] + ".mp3" 
        video = VideoFileClip(video_path)
        video.audio.write_audiofile(mp3_path)
        
        print(f"Converted to MP3: {mp3_path}")
        
        audio = AudioSegment.from_file(mp3_path)
        
        start_time = 10000  
        end_time = len(audio)  
        
        trimmed_audio = audio[start_time:end_time]
        
        trimmed_audio.export(mp3_path, format="mp3")
        
        print("Trimmed audio saved successfully")
        
    except Exception as e:
        print(f"Error downloading/converting {url}: {e}")
# Out:
# Downloaded: Night Changes
# MoviePy - Writing audio in /kaggle/working/Night Changes.mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/Night Changes.mp3
# Trimmed audio saved successfully
# Downloaded: Steal My Girl
# MoviePy - Writing audio in /kaggle/working/Steal My Girl.mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/Steal My Girl.mp3
# Trimmed audio saved successfully
# Downloaded: What Makes You Beautiful (Official Video)
# MoviePy - Writing audio in /kaggle/working/What Makes You Beautiful (Official Video).mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/What Makes You Beautiful (Official Video).mp3
# Trimmed audio saved successfully
# Downloaded: One Way Or Another (Teenage Kicks)
# MoviePy - Writing audio in /kaggle/working/One Way Or Another (Teenage Kicks).mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/One Way Or Another (Teenage Kicks).mp3
# Trimmed audio saved successfully
# Downloaded: Kiss You (Official)
# MoviePy - Writing audio in /kaggle/working/Kiss You (Official).mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/Kiss You (Official).mp3
# Trimmed audio saved successfully
# Downloaded: History (Official 4K Video)
# MoviePy - Writing audio in /kaggle/working/History (Official 4K Video).mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/History (Official 4K Video).mp3
# Trimmed audio saved successfully
# Downloaded: Perfect (Official Video)
# MoviePy - Writing audio in /kaggle/working/Perfect (Official Video).mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/Perfect (Official Video).mp3
# Trimmed audio saved successfully
# Downloaded: History (Official Video)
# MoviePy - Writing audio in /kaggle/working/History (Official Video).mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/History (Official Video).mp3
# Trimmed audio saved successfully
# Downloaded: Story of My Life (Official 4K Video)
# MoviePy - Writing audio in /kaggle/working/Story of My Life (Official 4K Video).mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/Story of My Life (Official 4K Video).mp3
# Trimmed audio saved successfully
# Downloaded: See You Again
# MoviePy - Writing audio in /kaggle/working/See You Again.mp3
# MoviePy - Done.
# Converted to MP3: /kaggle/working/See You Again.mp3
# Trimmed audio saved successfully

# %%
from pydub import AudioSegment

def merge_audio_files(file_paths, output_path):
    
    merged_audio = AudioSegment.empty()
    
    
    for file_path in file_paths:

        audio = AudioSegment.from_file(file_path)
        
        merged_audio += audio
    
    merged_audio.export(output_path, format="mp3")  

if __name__ == "__main__":
    file_paths = [
        "/kaggle/working/One Way Or Another (Teenage Kicks).mp3",
        "/kaggle/working/See You Again.mp3",
        "/kaggle/working/History (Official 4K Video).mp3",
        
    ]
    
    output_path = "/kaggle/working/merged_audio.mp3"
    
    merge_audio_files(file_paths, output_path)
